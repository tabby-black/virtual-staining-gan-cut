# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = np.array(Image.open("../datasets/histology/trainB/P4_ROI_02_C31_NT_rgb.png"))

# Rotate 90 degrees counter-clockwise
rotated = np.rot90(image, k=1)

# Other options:
rot90   = np.rot90(image, k=1)  # 90°
rot180  = np.rot90(image, k=2)  # 180°
rot270  = np.rot90(image, k=3)  # 270°

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Original")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(rotated)
plt.title("Rotated (90°)")
plt.axis('off')

plt.show()
